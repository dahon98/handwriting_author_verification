# %% [markdown]
# The code for pre-processing pictures of handwriting samples:
# the data are taken from local folder, cut into patches with 3 lines of handwriting and saved to local path. Patches of each author are saved into separated folders

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (2.4.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from pathlib import Path
import cv2
import numpy as np
import os
import shutil
from pathlib import Path

data_path = r"C:\Users\User\Desktop\vkr\data"

# %%
def extract_line_patches(
    image_path: str,
    output_dir: str = "./patches",
    author_id: str = "unknown",
    lines_per_patch: int = 3,
    max_height: int = 400
) -> int:
    '''Cuts images into patches with 3 lines of handwriting.
    Args:
        image_path: path to image
        output_dir: the path to folder to save patches,
        author_id: id of author,
        lines_per_patch: number of lines per patch,
        max_height: max height of patch'''

    # reading the image from path
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
   
    if img is None:
        return 0

    h, w = img.shape

    # Binarization
    _, binary = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Horizontal projection
    h_proj = np.sum(binary, axis=1) / 255

    # Searching for lines
    lines = []
    in_line = False
    start = 0
    noise_threshold = 50

    for y, val in enumerate(h_proj):
        if val > noise_threshold and not in_line:
            start = y
            in_line = True
        elif val <= noise_threshold and in_line:
            end = y
            if end - start > 15:  # minimal height of a line
                lines.append((start, end))
            in_line = False

    if in_line and h - start > 15:
        lines.append((start, h))

    # Filtering the lines. Use only lines in the center of image
    valid_lines = []
    for start_y, end_y in lines:
        if start_y < h * 0.3 or end_y > h * 0.70:
            continue
        valid_lines.append((start_y, end_y))

    # Grouping lines into patches
    patches_coords = []
    for i in range(0, len(valid_lines), lines_per_patch):
        group = valid_lines[i:i+lines_per_patch]
        if not group:
            continue

        y_start = group[0][0]
        y_end = group[-1][1]

        padding = 90
        y_start = max(0, y_start - padding)
        y_end = min(h, y_end + padding)

        patches_coords.append((y_start, y_end))

    # Saving and cropping
    image_name = Path(image_path).stem
    author_output_dir = os.path.join(output_dir, author_id)
    os.makedirs(author_output_dir, exist_ok=True)

    saved_count = 0
    for idx, (y1, y2) in enumerate(patches_coords):
        if y2 - y1 >= max_height:  # Saving patches with height > 400
            patch = img[y1:y2, 100:]
            
            # ===== CROP EMPTY BORDERS (left and right) =====
            # Find leftmost and rightmost non-black columns
            # In binarized image, text is white (255), background is black (0)
            # So we look for columns that have ANY white pixels
            
            # Vertical projection (sum of white pixels per column)
            _, patch_binary = cv2.threshold(patch, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
        
            # Vertical projection
            v_proj = np.sum(patch_binary, axis=0) / 255
        
            # Find columns with text
            text_cols = np.where(v_proj > 10)[0]
        
            if len(text_cols) > 0:
                left_crop = max(0, text_cols[0]-50)
                right_crop = min(patch.shape[1], text_cols[-1] + 50)
                patch = patch[:, left_crop:right_crop]
        
            # Save
            filename = f"{author_id}_{image_name}_patch{idx:03d}.png"
            filepath = os.path.join(author_output_dir, filename)
            cv2.imwrite(filepath, patch)
            saved_count += 1

    return saved_count

# %%
def process_all_authors(
    data_path: str,
    output_dir: str = None,
    lines_per_patch: int = 3,
    max_authors: int = None,
    max_height=400
):
    """
    Process all authors.

    Args:
        data_path: path to folder with images
        output_dir: the path to save patches
        lines_per_patch: the number of lines in 1 patch
        max_authors: max number of authors to process
        max_height: max height of a patch
    """
    # Define the input path
    if output_dir is None:
        output_dir = "/content/patches"

    # Geting all paths to authors' folders
    author_folders = []
    for item in os.listdir(data_path):
        item_path = os.path.join(data_path, item)
        if os.path.isdir(item_path) and item.isdigit():
            author_folders.append(item)

    author_folders.sort()
    if max_authors:
      author_folders = author_folders[:max_authors]
    total_images=0
    total_patches=0

    # Processing each author's folder
    for author_id in author_folders:
        author_path = os.path.join(data_path, author_id)

        # Getting all images of author
        image_files = []
        for file in os.listdir(author_path):
            if file.lower().endswith('.png'):
                image_files.append(file)

        image_files.sort()
        print(f"Images found: {len(image_files)}")

        author_images = 0
        author_patches = 0

        # Process each image
        for img_file in image_files:
            img_path = os.path.join(author_path, img_file)
        

            patches_count = extract_line_patches(
                image_path=img_path,
                output_dir=output_dir,
                author_id=author_id,
                lines_per_patch=lines_per_patch,
                max_height=max_height
            )
            if patches_count > 0:
                author_images += 1
                author_patches += patches_count

        if author_images > 0:
            print(f"Total images for author {author_id}: {author_images}, {author_patches} patches")
            total_images += author_images
            total_patches += author_patches
        else:
            print(f"No images for author {author_id}")


    print(f"Authors processed: {len(author_folders)}")
    print(f"Images processed: {total_images}")
    print(f"Total patches: {total_patches}")

# %%
content = os.listdir(data_path)
if "data" in content and os.path.isdir(os.path.join(data_path, "data")):
  data_path = os.path.join(data_path, "data")
  author_dirs = [d for d in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, d)) and d.isdigit()]
  process_all_authors(data_path=data_path, output_dir="/content/patches",  lines_per_patch=3,max_authors=1)

# %% [markdown]
# Now let's process images into 1 line per patch and save in separate folder

# %%
data_path = r'C:\Users\User\Desktop\vkr\content'
content = os.listdir(data_path)

if "data" in content and os.path.isdir(os.path.join(data_path, "data")):
 
  data_path = os.path.join(data_path, "data")
 
  author_dirs = [d for d in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, d)) and d.isdigit()]

  process_all_authors(data_path=data_path, output_dir=r"C:\Users\User\Desktop\vkr\patches_output",  lines_per_patch=1,max_authors=None, max_height=50)
# Out:
# Images found: 59
# Total images for author 000: 59, 433 patches
# Images found: 2
# Total images for author 001: 2, 11 patches
# Images found: 1
# Total images for author 002: 1, 8 patches
# Images found: 2
# Total images for author 003: 2, 15 patches
# Images found: 1
# Total images for author 004: 1, 7 patches
# Images found: 2
# Total images for author 005: 2, 11 patches
# Images found: 1
# Total images for author 006: 1, 5 patches
# Images found: 2
# Total images for author 007: 2, 16 patches
# Images found: 2
# Total images for author 008: 2, 16 patches
# Images found: 2
# Total images for author 009: 2, 16 patches
# Images found: 2
# Total images for author 010: 2, 16 patches
# Images found: 2
# Total images for author 011: 2, 15 patches
# Images found: 2
# Total images for author 012: 2, 16 patches
# Images found: 3
# Total images for author 013: 3, 20 patches
# Images found: 2
# Total images for author 014: 2, 16 patches
# Images found: 1
# Total images for author 015: 1, 7 patches
# Images found: 3
# Total images for author 016: 3, 25 patches
# Images found: 3
# Total images for author 017: 3, 24 patches
# Images found: 2
# Total images for author 018: 2, 10 patches
# Images found: 3
# Total images for author 019: 3, 21 patches
# Images found: 1
# Total images for author 020: 1, 8 patches
# Images found: 1
# Total images for author 021: 1, 6 patches
# Images found: 1
# Total images for author 022: 1, 8 patches
# Images found: 1
# Total images for author 023: 1, 7 patches
# Images found: 1
# Total images for author 024: 1, 8 patches
# Images found: 5
# Total images for author 025: 5, 28 patches
# Images found: 5
# Total images for author 026: 5, 34 patches
# Images found: 1
# Total images for author 027: 1, 6 patches
# Images found: 1
# Total images for author 028: 1, 7 patches
# Images found: 1
# Total images for author 029: 1, 7 patches
# Images found: 1
# Total images for author 030: 1, 7 patches
# Images found: 1
# Total images for author 031: 1, 7 patches
# Images found: 1
# Total images for author 032: 1, 8 patches
# Images found: 1
# Total images for author 033: 1, 7 patches
# Images found: 1
# Total images for author 034: 1, 7 patches
# Images found: 1
# Total images for author 035: 1, 6 patches
# Images found: 1
# Total images for author 036: 1, 6 patches
# Images found: 5
# Total images for author 037: 5, 34 patches
# Images found: 1
# Total images for author 038: 1, 7 patches
# Images found: 1
# Total images for author 039: 1, 8 patches
# Images found: 1
# Total images for author 040: 1, 8 patches
# Images found: 1
# Total images for author 041: 1, 6 patches
# Images found: 1
# Total images for author 042: 1, 7 patches
# Images found: 1
# Total images for author 043: 1, 7 patches
# Images found: 1
# Total images for author 044: 1, 7 patches
# Images found: 1
# Total images for author 045: 1, 7 patches
# Images found: 1
# Total images for author 046: 1, 8 patches
# Images found: 1
# Total images for author 047: 1, 8 patches
# Images found: 1
# Total images for author 048: 1, 8 patches
# Images found: 1
# Total images for author 049: 1, 6 patches
# Images found: 1
# Total images for author 050: 1, 6 patches
# Images found: 1
# Total images for author 051: 1, 5 patches
# Images found: 1
# Total images for author 052: 1, 7 patches
# Images found: 1
# Total images for author 053: 1, 10 patches
# Images found: 1
# Total images for author 054: 1, 8 patches
# Images found: 1
# Total images for author 055: 1, 7 patches
# Images found: 1
# Total images for author 056: 1, 6 patches
# Images found: 4
# Total images for author 058: 4, 25 patches
# Images found: 4
# Total images for author 059: 4, 25 patches
# Images found: 4
# Total images for author 060: 4, 31 patches
# Images found: 4
# Total images for author 061: 4, 23 patches
# Images found: 3
# Total images for author 062: 3, 22 patches
# Images found: 3
# Total images for author 063: 3, 24 patches
# Images found: 4
# Total images for author 064: 4, 30 patches
# Images found: 2
# Total images for author 065: 2, 14 patches
# Images found: 2
# Total images for author 066: 2, 13 patches
# Images found: 1
# Total images for author 067: 1, 6 patches
# Images found: 1
# Total images for author 068: 1, 9 patches
# Images found: 1
# Total images for author 069: 1, 4 patches
# Images found: 1
# Total images for author 070: 1, 7 patches
# Images found: 1
# Total images for author 071: 1, 5 patches
# Images found: 1
# Total images for author 072: 1, 8 patches
# Images found: 1
# Total images for author 073: 1, 5 patches
# Images found: 1
# Total images for author 074: 1, 7 patches
# Images found: 1
# Total images for author 075: 1, 4 patches
# Images found: 1
# Total images for author 076: 1, 8 patches
# Images found: 1
# Total images for author 077: 1, 7 patches
# Images found: 1
# Total images for author 078: 1, 6 patches
# Images found: 1
# Total images for author 079: 1, 7 patches
# Images found: 1
# Total images for author 080: 1, 8 patches
# Images found: 2
# Total images for author 081: 2, 10 patches
# Images found: 1
# Total images for author 082: 1, 6 patches
# Images found: 1
# Total images for author 083: 1, 8 patches
# Images found: 2
# Total images for author 084: 2, 16 patches
# Images found: 6
# Total images for author 085: 6, 30 patches
# Images found: 1
# Total images for author 086: 1, 8 patches
# Images found: 3
# Total images for author 087: 3, 17 patches
# Images found: 3
# Total images for author 088: 3, 18 patches
# Images found: 3
# Total images for author 089: 3, 19 patches
# Images found: 3
# Total images for author 090: 3, 17 patches
# Images found: 2
# Total images for author 091: 2, 16 patches
# Images found: 3
# Total images for author 092: 3, 22 patches
# Images found: 3
# Total images for author 093: 3, 20 patches
# Images found: 3
# Total images for author 094: 3, 21 patches
# Images found: 2
# Total images for author 095: 2, 16 patches
# Images found: 1
# Total images for author 096: 1, 7 patches
# Images found: 1
# Total images for author 097: 1, 7 patches
# Images found: 1
# Total images for author 098: 1, 5 patches
# Images found: 1
# Total images for author 099: 1, 3 patches
# Images found: 1
# Total images for author 100: 1, 5 patches
# Images found: 2
# Total images for author 102: 2, 9 patches
# Images found: 1
# Total images for author 103: 1, 8 patches
# Images found: 1
# Total images for author 104: 1, 8 patches
# Images found: 1
# Total images for author 105: 1, 7 patches
# Images found: 1
# Total images for author 106: 1, 7 patches
# Images found: 4
# Total images for author 107: 4, 27 patches
# Images found: 4
# Total images for author 108: 4, 17 patches
# Images found: 4
# Total images for author 109: 4, 19 patches
# Images found: 4
# Total images for author 110: 4, 22 patches
# Images found: 4
# Total images for author 111: 4, 24 patches
# Images found: 4
# Total images for author 112: 4, 27 patches
# Images found: 4
# Total images for author 113: 4, 25 patches
# Images found: 4
# Total images for author 114: 3, 16 patches
# Images found: 1
# Total images for author 115: 1, 4 patches
# Images found: 1
# Total images for author 116: 1, 8 patches
# Images found: 4
# Total images for author 117: 4, 29 patches
# Images found: 7
# Total images for author 118: 7, 31 patches
# Images found: 2
# Total images for author 119: 2, 16 patches
# Images found: 1
# Total images for author 120: 1, 9 patches
# Images found: 2
# Total images for author 121: 2, 14 patches
# Images found: 1
# Total images for author 122: 1, 6 patches
# Images found: 5
# Total images for author 123: 5, 31 patches
# Images found: 4
# Total images for author 124: 4, 29 patches
# Images found: 5
# Total images for author 125: 5, 34 patches
# Images found: 5
# Total images for author 126: 5, 26 patches
# Images found: 3
# Total images for author 127: 3, 26 patches
# Images found: 5
# Total images for author 128: 5, 37 patches
# Images found: 4
# Total images for author 129: 4, 31 patches
# Images found: 5
# Total images for author 130: 5, 31 patches
# Images found: 4
# Total images for author 131: 4, 27 patches
# Images found: 4
# Total images for author 132: 4, 24 patches
# Images found: 5
# Total images for author 133: 5, 40 patches
# Images found: 2
# Total images for author 134: 2, 13 patches
# Images found: 2
# Total images for author 135: 2, 17 patches
# Images found: 1
# Total images for author 136: 1, 8 patches
# Images found: 1
# Total images for author 137: 1, 8 patches
# Images found: 1
# Total images for author 138: 1, 7 patches
# Images found: 2
# Total images for author 139: 2, 15 patches
# Images found: 2
# Total images for author 140: 2, 15 patches
# Images found: 1
# Total images for author 141: 1, 8 patches
# Images found: 1
# Total images for author 142: 1, 8 patches
# Images found: 1
# Total images for author 143: 1, 4 patches
# Images found: 1
# Total images for author 144: 1, 7 patches
# Images found: 1
# Total images for author 145: 1, 7 patches
# Images found: 1
# Total images for author 146: 1, 7 patches
# Images found: 1
# Total images for author 147: 1, 8 patches
# Images found: 1
# Total images for author 148: 1, 8 patches
# Images found: 1
# Total images for author 149: 1, 5 patches
# Images found: 10
# Total images for author 150: 10, 68 patches
# Images found: 10
# Total images for author 151: 10, 68 patches
# Images found: 10
# Total images for author 152: 10, 67 patches
# Images found: 10
# Total images for author 153: 10, 74 patches
# Images found: 10
# Total images for author 154: 10, 74 patches
# Images found: 9
# Total images for author 155: 9, 68 patches
# Images found: 1
# Total images for author 156: 1, 6 patches
# Images found: 2
# Total images for author 157: 2, 9 patches
# Images found: 3
# Total images for author 158: 3, 19 patches
# Images found: 2
# Total images for author 159: 2, 12 patches
# Images found: 2
# Total images for author 160: 2, 10 patches
# Images found: 2
# Total images for author 161: 2, 13 patches
# Images found: 2
# Total images for author 162: 2, 14 patches
# Images found: 2
# Total images for author 163: 2, 12 patches
# Images found: 2
# Total images for author 164: 2, 13 patches
# Images found: 2
# Total images for author 165: 2, 11 patches
# Images found: 2
# Total images for author 166: 2, 11 patches
# Images found: 1
# Total images for author 167: 1, 6 patches
# Images found: 2
# Total images for author 168: 2, 4 patches
# Images found: 2
# Total images for author 169: 2, 9 patches
# Images found: 2
# Total images for author 170: 2, 12 patches
# Images found: 2
# Total images for author 171: 2, 14 patches
# Images found: 2
# Total images for author 172: 2, 10 patches
# Images found: 5
# Total images for author 173: 5, 38 patches
# Images found: 5
# Total images for author 174: 5, 24 patches
# Images found: 2
# Total images for author 175: 2, 6 patches
# Images found: 1
# Total images for author 176: 1, 6 patches
# Images found: 2
# Total images for author 177: 2, 14 patches
# Images found: 2
# Total images for author 178: 2, 16 patches
# Images found: 2
# Total images for author 179: 2, 13 patches
# Images found: 2
# Total images for author 180: 2, 13 patches
# Images found: 3
# Total images for author 181: 3, 19 patches
# Images found: 1
# Total images for author 182: 1, 7 patches
# Images found: 1
# Total images for author 183: 1, 7 patches
# Images found: 2
# Total images for author 184: 2, 10 patches
# Images found: 2
# Total images for author 185: 2, 15 patches
# Images found: 2
# Total images for author 186: 2, 10 patches
# Images found: 2
# Total images for author 187: 2, 13 patches
# Images found: 2
# Total images for author 188: 2, 15 patches
# Images found: 1
# Total images for author 189: 1, 4 patches
# Images found: 2
# Total images for author 190: 2, 8 patches
# Images found: 1
# Total images for author 191: 1, 7 patches
# Images found: 2
# Total images for author 192: 2, 13 patches
# Images found: 4
# Total images for author 193: 4, 30 patches
# Images found: 2
# Total images for author 194: 2, 10 patches
# Images found: 2
# Total images for author 195: 2, 10 patches
# Images found: 1
# Total images for author 196: 1, 8 patches
# Images found: 2
# Total images for author 197: 2, 10 patches
# Images found: 2
# Total images for author 198: 2, 9 patches
# Images found: 4
# Total images for author 199: 4, 29 patches
# Images found: 1
# Total images for author 200: 1, 8 patches
# Images found: 1
# Total images for author 201: 1, 4 patches
# Images found: 5
# Total images for author 202: 5, 38 patches
# Images found: 5
# Total images for author 203: 5, 24 patches
# Images found: 5
# Total images for author 204: 5, 40 patches
# Images found: 5
# Total images for author 205: 5, 38 patches
# Images found: 5
# Total images for author 206: 5, 33 patches
# Images found: 5
# Total images for author 207: 5, 36 patches
# Images found: 5
# Total images for author 208: 5, 30 patches
# Images found: 7
# Total images for author 209: 7, 50 patches
# Images found: 2
# Total images for author 210: 2, 12 patches
# Images found: 2
# Total images for author 211: 2, 13 patches
# Images found: 3
# Total images for author 212: 3, 21 patches
# Images found: 3
# Total images for author 213: 3, 17 patches
# Images found: 2
# Total images for author 214: 2, 8 patches
# Images found: 2
# Total images for author 215: 2, 13 patches
# Images found: 2
# Total images for author 216: 2, 14 patches
# Images found: 3
# Total images for author 217: 3, 21 patches
# Images found: 1
# Total images for author 218: 1, 6 patches
# Images found: 1
# Total images for author 219: 1, 5 patches
# Images found: 1
# Total images for author 220: 1, 5 patches
# Images found: 1
# Total images for author 221: 1, 7 patches
# Images found: 1
# Total images for author 222: 1, 8 patches
# Images found: 1
# Total images for author 223: 1, 8 patches
# Images found: 1
# Total images for author 224: 1, 7 patches
# Images found: 1
# Total images for author 225: 1, 8 patches
# Images found: 1
# Total images for author 226: 1, 7 patches
# Images found: 1
# Total images for author 227: 1, 8 patches
# Images found: 1
# Total images for author 228: 1, 4 patches
# Images found: 1
# Total images for author 229: 1, 7 patches
# Images found: 2
# Total images for author 230: 2, 8 patches
# Images found: 2
# Total images for author 231: 2, 13 patches
# Images found: 2
# Total images for author 232: 2, 13 patches
# Images found: 2
# Total images for author 233: 2, 10 patches
# Images found: 2
# Total images for author 234: 2, 11 patches
# Images found: 2
# Total images for author 235: 2, 12 patches
# Images found: 1
# Total images for author 236: 1, 5 patches
# Images found: 2
# Total images for author 237: 2, 12 patches
# Images found: 1
# Total images for author 238: 1, 7 patches
# Images found: 4
# Total images for author 239: 4, 28 patches
# Images found: 2
# Total images for author 240: 2, 11 patches
# Images found: 4
# Total images for author 241: 4, 16 patches
# Images found: 3
# Total images for author 242: 3, 16 patches
# Images found: 3
# Total images for author 243: 3, 14 patches
# Images found: 1
# Total images for author 244: 1, 8 patches
# Images found: 1
# Total images for author 245: 1, 7 patches
# Images found: 4
# Total images for author 246: 4, 32 patches
# Images found: 5
# Total images for author 247: 5, 41 patches
# Images found: 5
# Total images for author 248: 5, 37 patches
# Images found: 1
# Total images for author 249: 1, 4 patches
# Images found: 2
# Total images for author 250: 2, 16 patches
# Images found: 1
# Total images for author 251: 1, 8 patches
# Images found: 1
# Total images for author 252: 1, 7 patches
# Images found: 1
# Total images for author 253: 1, 8 patches
# Images found: 2
# Total images for author 254: 2, 9 patches
# Images found: 1
# Total images for author 255: 1, 8 patches
# Images found: 2
# Total images for author 256: 2, 12 patches
# Images found: 1
# Total images for author 257: 1, 7 patches
# Images found: 1
# Total images for author 258: 1, 4 patches
# Images found: 2
# Total images for author 259: 2, 15 patches
# Images found: 1
# Total images for author 260: 1, 6 patches
# Images found: 1
# Total images for author 261: 1, 5 patches
# Images found: 1
# Total images for author 262: 1, 8 patches
# Images found: 1
# Total images for author 263: 1, 8 patches
# Images found: 1
# Total images for author 264: 1, 7 patches
# Images found: 1
# Total images for author 265: 1, 7 patches
# Images found: 1
# Total images for author 266: 1, 8 patches
# Images found: 1
# Total images for author 267: 1, 5 patches
# Images found: 1
# Total images for author 268: 1, 3 patches
# Images found: 1
# Total images for author 269: 1, 6 patches
# Images found: 1
# Total images for author 270: 1, 5 patches
# Images found: 3
# Total images for author 272: 3, 19 patches
# Images found: 5
# Total images for author 273: 5, 35 patches
# Images found: 5
# Total images for author 274: 5, 27 patches
# Images found: 2
# Total images for author 275: 2, 14 patches
# Images found: 2
# Total images for author 276: 2, 13 patches
# Images found: 2
# Total images for author 277: 2, 15 patches
# Images found: 2
# Total images for author 278: 2, 9 patches
# Images found: 2
# Total images for author 279: 2, 13 patches
# Images found: 2
# Total images for author 280: 2, 13 patches
# Images found: 2
# Total images for author 281: 2, 14 patches
# Images found: 2
# Total images for author 282: 2, 15 patches
# Images found: 2
# Total images for author 283: 2, 11 patches
# Images found: 5
# Total images for author 285: 5, 29 patches
# Images found: 4
# Total images for author 286: 4, 28 patches
# Images found: 5
# Total images for author 287: 5, 41 patches
# Images found: 5
# Total images for author 288: 5, 34 patches
# Images found: 5
# Total images for author 289: 5, 36 patches
# Images found: 1
# Total images for author 290: 1, 7 patches
# Images found: 4
# Total images for author 291: 4, 29 patches
# Images found: 5
# Total images for author 292: 5, 34 patches
# Images found: 5
# Total images for author 293: 5, 25 patches
# Images found: 4
# Total images for author 294: 4, 28 patches
# Images found: 2
# Total images for author 295: 2, 12 patches
# Images found: 3
# Total images for author 296: 3, 19 patches
# Images found: 3
# Total images for author 297: 3, 24 patches
# Images found: 3
# Total images for author 298: 3, 24 patches
# Images found: 3
# Total images for author 299: 3, 24 patches
# Images found: 3
# Total images for author 300: 3, 23 patches
# Images found: 2
# Total images for author 301: 2, 12 patches
# Images found: 1
# Total images for author 302: 1, 8 patches
# Images found: 1
# Total images for author 303: 1, 6 patches
# Images found: 1
# Total images for author 304: 1, 8 patches
# Images found: 1
# Total images for author 305: 1, 8 patches
# Images found: 1
# Total images for author 307: 1, 4 patches
# Images found: 1
# Total images for author 308: 1, 8 patches
# Images found: 1
# Total images for author 309: 1, 2 patches
# Images found: 1
# Total images for author 310: 1, 6 patches
# Images found: 1
# Total images for author 312: 1, 6 patches
# Images found: 1
# Total images for author 313: 1, 6 patches
# Images found: 1
# Total images for author 314: 1, 7 patches
# Images found: 7
# Total images for author 315: 7, 46 patches
# Images found: 1
# Total images for author 316: 1, 7 patches
# Images found: 1
# Total images for author 317: 1, 5 patches
# Images found: 1
# Total images for author 318: 1, 5 patches
# Images found: 1
# Total images for author 319: 1, 6 patches
# Images found: 2
# Total images for author 320: 2, 12 patches
# Images found: 2
# Total images for author 321: 2, 13 patches
# Images found: 1
# Total images for author 322: 1, 5 patches
# Images found: 1
# Total images for author 323: 1, 7 patches
# Images found: 2
# Total images for author 324: 2, 13 patches
# Images found: 2
# Total images for author 325: 2, 14 patches
# Images found: 1
# Total images for author 326: 1, 5 patches
# Images found: 1
# Total images for author 327: 1, 4 patches
# Images found: 2
# Total images for author 328: 2, 16 patches
# Images found: 2
# Total images for author 329: 2, 10 patches
# Images found: 4
# Total images for author 330: 4, 25 patches
# Images found: 1
# Total images for author 331: 1, 5 patches
# Images found: 8
# Total images for author 332: 8, 50 patches
# Images found: 9
# Total images for author 333: 9, 60 patches
# Images found: 9
# Total images for author 334: 9, 55 patches
# Images found: 8
# Total images for author 335: 8, 41 patches
# Images found: 9
# Total images for author 336: 9, 49 patches
# Images found: 9
# Total images for author 337: 9, 40 patches
# Images found: 9
# Total images for author 338: 9, 41 patches
# Images found: 9
# Total images for author 339: 9, 54 patches
# Images found: 9
# Total images for author 340: 9, 48 patches
# Images found: 9
# Total images for author 341: 9, 60 patches
# Images found: 9
# Total images for author 342: 9, 58 patches
# Images found: 9
# Total images for author 343: 9, 48 patches
# Images found: 9
# Total images for author 344: 9, 54 patches
# Images found: 9
# Total images for author 345: 9, 64 patches
# Images found: 9
# Total images for author 346: 9, 70 patches
# Images found: 9
# Total images for author 347: 9, 49 patches
# Images found: 9
# Total images for author 348: 9, 48 patches
# Images found: 9
# Total images for author 349: 9, 50 patches
# Images found: 4
# Total images for author 350: 4, 22 patches
# Images found: 5
# Total images for author 351: 5, 33 patches
# Images found: 5
# Total images for author 352: 5, 31 patches
# Images found: 5
# Total images for author 353: 5, 38 patches
# Images found: 5
# Total images for author 354: 5, 33 patches
# Images found: 5
# Total images for author 355: 5, 31 patches
# Images found: 2
# Total images for author 356: 2, 16 patches
# Images found: 3
# Total images for author 357: 3, 18 patches
# Images found: 1
# Total images for author 359: 1, 8 patches
# Images found: 1
# Total images for author 360: 1, 7 patches
# Images found: 1
# Total images for author 361: 1, 7 patches
# Images found: 1
# Total images for author 362: 1, 7 patches
# Images found: 1
# Total images for author 363: 1, 5 patches
# Images found: 2
# Total images for author 364: 2, 13 patches
# Images found: 1
# Total images for author 365: 1, 6 patches
# Images found: 1
# Total images for author 366: 1, 7 patches
# Images found: 1
# Total images for author 367: 1, 7 patches
# Images found: 1
# Total images for author 368: 1, 6 patches
# Images found: 1
# Total images for author 369: 1, 7 patches
# Images found: 1
# Total images for author 370: 1, 8 patches
# Images found: 1
# Total images for author 371: 1, 11 patches
# Images found: 1
# Total images for author 372: 1, 8 patches
# Images found: 1
# Total images for author 373: 1, 8 patches
# Images found: 1
# Total images for author 375: 1, 6 patches
# Images found: 1
# Total images for author 376: 1, 8 patches
# Images found: 1
# Total images for author 377: 1, 6 patches
# Images found: 1
# Total images for author 378: 1, 8 patches
# Images found: 2
# Total images for author 379: 2, 15 patches
# Images found: 2
# Total images for author 380: 2, 15 patches
# Images found: 2
# Total images for author 382: 2, 10 patches
# Images found: 2
# Total images for author 383: 2, 16 patches
# Images found: 10
# Total images for author 384: 10, 74 patches
# Images found: 5
# Total images for author 385: 5, 38 patches
# Images found: 5
# Total images for author 386: 5, 41 patches
# Images found: 5
# Total images for author 387: 5, 36 patches
# Images found: 3
# Total images for author 388: 3, 22 patches
# Images found: 5
# Total images for author 389: 5, 29 patches
# Images found: 5
# Total images for author 390: 5, 34 patches
# Images found: 5
# Total images for author 391: 5, 32 patches
# Images found: 4
# Total images for author 392: 4, 25 patches
# Images found: 5
# Total images for author 393: 4, 24 patches
# Images found: 2
# Total images for author 394: 2, 16 patches
# Images found: 1
# Total images for author 395: 1, 5 patches
# Images found: 1
# Total images for author 396: 1, 7 patches
# Images found: 1
# Total images for author 397: 1, 5 patches
# Images found: 1
# Total images for author 398: 1, 8 patches
# Images found: 1
# Total images for author 399: 1, 5 patches
# Images found: 1
# Total images for author 400: 1, 7 patches
# Images found: 1
# Total images for author 401: 1, 8 patches
# Images found: 1
# Total images for author 402: 1, 7 patches
# Images found: 2
# Total images for author 403: 2, 16 patches
# Images found: 1
# Total images for author 404: 1, 7 patches
# Images found: 2
# Total images for author 405: 2, 16 patches
# Images found: 1
# Total images for author 406: 1, 5 patches
# Images found: 1
# Total images for author 407: 1, 5 patches
# Images found: 2
# Total images for author 408: 2, 11 patches
# Images found: 2
# Total images for author 409: 2, 11 patches
# Images found: 1
# Total images for author 410: 1, 5 patches
# Images found: 1
# Total images for author 411: 1, 7 patches
# Images found: 1
# Total images for author 412: 1, 8 patches
# Images found: 1
# Total images for author 413: 1, 5 patches
# Images found: 2
# Total images for author 414: 2, 13 patches
# Images found: 7
# Total images for author 415: 7, 55 patches
# Images found: 1
# Total images for author 416: 1, 7 patches
# Images found: 1
# Total images for author 417: 1, 8 patches
# Images found: 1
# Total images for author 418: 1, 6 patches
# Images found: 1
# Total images for author 419: 1, 3 patches
# Images found: 2
# Total images for author 420: 2, 8 patches
# Images found: 1
# Total images for author 421: 1, 6 patches
# Images found: 1
# Total images for author 422: 1, 6 patches
# Images found: 1
# Total images for author 423: 1, 8 patches
# Images found: 1
# Total images for author 424: 1, 6 patches
# Images found: 1
# Total images for author 425: 1, 8 patches
# Images found: 1
# Total images for author 426: 1, 4 patches
# Images found: 1
# Total images for author 427: 1, 8 patches
# Images found: 1
# Total images for author 428: 1, 6 patches
# Images found: 1
# Total images for author 429: 1, 5 patches
# Images found: 1
# Total images for author 430: 1, 8 patches
# Images found: 1
# Total images for author 431: 1, 7 patches
# Images found: 1
# Total images for author 432: 1, 6 patches
# Images found: 1
# Total images for author 433: 1, 7 patches
# Images found: 1
# Total images for author 434: 1, 6 patches
# Images found: 1
# Total images for author 435: 1, 4 patches
# Images found: 1
# Total images for author 436: 1, 7 patches
# Images found: 2
# Total images for author 439: 2, 11 patches
# Images found: 1
# Total images for author 440: 1, 8 patches
# Images found: 1
# Total images for author 441: 1, 5 patches
# Images found: 2
# Total images for author 442: 2, 13 patches
# Images found: 2
# Total images for author 443: 2, 12 patches
# Images found: 2
# Total images for author 444: 2, 15 patches
# Images found: 2
# Total images for author 445: 2, 12 patches
# Images found: 2
# Total images for author 446: 2, 12 patches
# Images found: 2
# Total images for author 447: 2, 13 patches
# Images found: 2
# Total images for author 448: 2, 11 patches
# Images found: 2
# Total images for author 449: 2, 10 patches
# Images found: 2
# Total images for author 450: 2, 14 patches
# Images found: 2
# Total images for author 451: 2, 12 patches
# Images found: 2
# Total images for author 452: 2, 10 patches
# Images found: 2
# Total images for author 453: 2, 13 patches
# Images found: 5
# Total images for author 454: 5, 22 patches
# Images found: 5
# Total images for author 455: 5, 26 patches
# Images found: 5
# Total images for author 456: 5, 33 patches
# Images found: 1
# Total images for author 457: 1, 7 patches
# Images found: 3
# Total images for author 458: 3, 14 patches
# Images found: 1
# Total images for author 459: 1, 7 patches
# Images found: 1
# Total images for author 460: 1, 6 patches
# Images found: 1
# Total images for author 461: 1, 8 patches
# Images found: 1
# Total images for author 462: 1, 3 patches
# Images found: 1
# Total images for author 463: 1, 7 patches
# Images found: 1
# Total images for author 464: 1, 8 patches
# Images found: 1
# Total images for author 465: 1, 7 patches
# Images found: 1
# Total images for author 466: 1, 6 patches
# Images found: 1
# Total images for author 467: 1, 5 patches
# Images found: 1
# Total images for author 468: 1, 7 patches
# Images found: 1
# Total images for author 469: 1, 4 patches
# Images found: 1
# Total images for author 470: 1, 5 patches
# Images found: 1
# Total images for author 471: 1, 6 patches
# Images found: 1
# Total images for author 472: 1, 6 patches
# Images found: 1
# Total images for author 473: 1, 8 patches
# Images found: 1
# Total images for author 474: 1, 6 patches
# Images found: 1
# Total images for author 475: 1, 8 patches
# Images found: 1
# Total images for author 476: 1, 6 patches
# Images found: 1
# Total images for author 477: 1, 8 patches
# Images found: 1
# Total images for author 478: 1, 8 patches
# Images found: 1
# Total images for author 479: 1, 3 patches
# Images found: 2
# Total images for author 480: 2, 11 patches
# Images found: 2
# Total images for author 481: 2, 11 patches
# Images found: 2
# Total images for author 482: 2, 13 patches
# Images found: 2
# Total images for author 483: 2, 15 patches
# Images found: 2
# Total images for author 484: 2, 12 patches
# Images found: 1
# Total images for author 485: 1, 6 patches
# Images found: 2
# Total images for author 486: 2, 9 patches
# Images found: 2
# Total images for author 487: 2, 13 patches
# Images found: 2
# Total images for author 488: 2, 9 patches
# Images found: 2
# Total images for author 489: 2, 13 patches
# Images found: 2
# Total images for author 490: 2, 15 patches
# Images found: 2
# Total images for author 491: 2, 9 patches
# Images found: 2
# Total images for author 492: 2, 13 patches
# Images found: 2
# Total images for author 493: 2, 13 patches
# Images found: 2
# Total images for author 494: 2, 9 patches
# Images found: 3
# Total images for author 495: 3, 9 patches
# Images found: 4
# Total images for author 496: 4, 25 patches
# Images found: 4
# Total images for author 497: 4, 24 patches
# Images found: 5
# Total images for author 498: 5, 25 patches
# Images found: 1
# Total images for author 499: 1, 6 patches
# Images found: 1
# Total images for author 500: 1, 8 patches
# Images found: 1
# Total images for author 501: 1, 5 patches
# Images found: 1
# Total images for author 502: 1, 4 patches
# Images found: 1
# Total images for author 503: 1, 7 patches
# Images found: 1
# Total images for author 504: 1, 8 patches
# Images found: 1
# Total images for author 505: 1, 8 patches
# Images found: 1
# Total images for author 506: 1, 8 patches
# Images found: 1
# Total images for author 508: 1, 5 patches
# Images found: 1
# Total images for author 509: 1, 4 patches
# Images found: 1
# Total images for author 510: 1, 6 patches
# Images found: 1
# Total images for author 511: 1, 6 patches
# Images found: 1
# Total images for author 512: 1, 6 patches
# Images found: 2
# Total images for author 513: 2, 13 patches
# Images found: 2
# Total images for author 514: 2, 12 patches
# Images found: 1
# Total images for author 515: 1, 7 patches
# Images found: 1
# Total images for author 516: 1, 9 patches
# Images found: 1
# Total images for author 517: 1, 8 patches
# Images found: 1
# Total images for author 518: 1, 6 patches
# Images found: 1
# Total images for author 519: 1, 5 patches
# Images found: 1
# Total images for author 520: 1, 8 patches
# Images found: 1
# Total images for author 521: 1, 3 patches
# Images found: 1
# Total images for author 522: 1, 9 patches
# Images found: 1
# Total images for author 523: 1, 5 patches
# Images found: 1
# Total images for author 524: 1, 4 patches
# Images found: 1
# Total images for author 525: 1, 8 patches
# Images found: 1
# Total images for author 526: 1, 5 patches
# Images found: 2
# Total images for author 527: 2, 14 patches
# Images found: 1
# Total images for author 528: 1, 8 patches
# Images found: 1
# Total images for author 529: 1, 8 patches
# Images found: 1
# Total images for author 530: 1, 6 patches
# Images found: 1
# Total images for author 531: 1, 8 patches
# Images found: 1
# Total images for author 532: 1, 8 patches
# Images found: 1
# Total images for author 533: 1, 7 patches
# Images found: 1
# Total images for author 534: 1, 7 patches
# Images found: 1
# Total images for author 535: 1, 4 patches
# Images found: 1
# Total images for author 536: 1, 8 patches
# Images found: 1
# Total images for author 537: 1, 5 patches
# Images found: 1
# Total images for author 538: 1, 4 patches
# Images found: 1
# Total images for author 539: 1, 6 patches
# Images found: 1
# Total images for author 540: 1, 7 patches
# Images found: 1
# Total images for author 541: 1, 7 patches
# Images found: 2
# Total images for author 542: 2, 16 patches
# Images found: 1
# Total images for author 543: 1, 4 patches
# Images found: 5
# Total images for author 544: 5, 36 patches
# Images found: 4
# Total images for author 545: 4, 12 patches
# Images found: 5
# Total images for author 546: 5, 36 patches
# Images found: 5
# Total images for author 547: 5, 37 patches
# Images found: 5
# Total images for author 548: 5, 29 patches
# Images found: 5
# Total images for author 549: 5, 30 patches
# Images found: 5
# Total images for author 550: 5, 23 patches
# Images found: 10
# Total images for author 551: 10, 65 patches
# Images found: 10
# Total images for author 552: 10, 53 patches
# Images found: 2
# Total images for author 553: 2, 13 patches
# Images found: 1
# Total images for author 554: 1, 5 patches
# Images found: 3
# Total images for author 555: 3, 23 patches
# Images found: 1
# Total images for author 556: 1, 4 patches
# Images found: 1
# Total images for author 557: 1, 7 patches
# Images found: 1
# Total images for author 558: 1, 8 patches
# Images found: 2
# Total images for author 559: 2, 12 patches
# Images found: 2
# Total images for author 560: 2, 13 patches
# Images found: 2
# Total images for author 561: 2, 11 patches
# Images found: 2
# Total images for author 562: 2, 15 patches
# Images found: 2
# Total images for author 563: 2, 13 patches
# Images found: 1
# Total images for author 564: 1, 8 patches
# Images found: 1
# Total images for author 565: 1, 7 patches
# Images found: 1
# Total images for author 566: 1, 5 patches
# Images found: 6
# Total images for author 567: 6, 47 patches
# Images found: 1
# Total images for author 568: 1, 8 patches
# Images found: 1
# Total images for author 569: 1, 5 patches
# Images found: 1
# Total images for author 570: 1, 7 patches
# Images found: 1
# Total images for author 571: 1, 4 patches
# Images found: 1
# Total images for author 572: 1, 4 patches
# Images found: 1
# Total images for author 573: 1, 7 patches
# Images found: 1
# Total images for author 574: 1, 5 patches
# Images found: 1
# Total images for author 575: 1, 5 patches
# Images found: 1
# Total images for author 576: 1, 7 patches
# Images found: 2
# Total images for author 577: 2, 15 patches
# Images found: 1
# Total images for author 578: 1, 8 patches
# Images found: 1
# Total images for author 579: 1, 8 patches
# Images found: 1
# Total images for author 580: 1, 8 patches
# Images found: 1
# Total images for author 581: 1, 3 patches
# Images found: 5
# Total images for author 582: 5, 31 patches
# Images found: 5
# Total images for author 583: 5, 32 patches
# Images found: 5
# Total images for author 584: 5, 29 patches
# Images found: 5
# Total images for author 585: 5, 32 patches
# Images found: 4
# Total images for author 586: 4, 19 patches
# Images found: 4
# Total images for author 587: 4, 30 patches
# Images found: 10
# Total images for author 588: 10, 64 patches
# Images found: 1
# Total images for author 589: 1, 8 patches
# Images found: 1
# Total images for author 590: 1, 8 patches
# Images found: 1
# Total images for author 591: 1, 6 patches
# Images found: 1
# Total images for author 592: 1, 7 patches
# Images found: 1
# Total images for author 593: 1, 6 patches
# Images found: 1
# Total images for author 594: 1, 8 patches
# Images found: 1
# Total images for author 595: 1, 6 patches
# Images found: 1
# Total images for author 596: 1, 7 patches
# Images found: 1
# Total images for author 597: 1, 3 patches
# Images found: 2
# Total images for author 598: 2, 15 patches
# Images found: 2
# Total images for author 599: 2, 16 patches
# Images found: 1
# Total images for author 600: 1, 6 patches
# Images found: 1
# Total images for author 601: 1, 6 patches
# Images found: 1
# Total images for author 602: 1, 7 patches
# Images found: 1
# Total images for author 603: 1, 7 patches
# Images found: 1
# Total images for author 604: 1, 3 patches
# Images found: 1
# Total images for author 605: 1, 5 patches
# Images found: 1
# Total images for author 606: 1, 6 patches
# Images found: 1
# Total images for author 607: 1, 7 patches
# Images found: 1
# Total images for author 608: 1, 4 patches
# Images found: 1
# Total images for author 609: 1, 7 patches
# Images found: 1
# Total images for author 610: 1, 7 patches
# Images found: 1
# No images for author 611
# Images found: 1
# Total images for author 612: 1, 8 patches
# Images found: 1
# Total images for author 613: 1, 5 patches
# Images found: 1
# Total images for author 614: 1, 8 patches
# Images found: 1
# Total images for author 615: 1, 3 patches
# Images found: 1
# Total images for author 616: 1, 6 patches
# Images found: 1
# Total images for author 617: 1, 9 patches
# Images found: 1
# Total images for author 618: 1, 4 patches
# Images found: 1
# Total images for author 619: 1, 7 patches
# Images found: 1
# Total images for author 620: 1, 8 patches
# Images found: 1
# Total images for author 621: 1, 5 patches
# Images found: 1
# Total images for author 622: 1, 6 patches
# Images found: 1
# Total images for author 623: 1, 5 patches
# Images found: 1
# Total images for author 624: 1, 5 patches
# Images found: 1
# Total images for author 625: 1, 4 patches
# Images found: 1
# Total images for author 626: 1, 5 patches
# Images found: 1
# Total images for author 627: 1, 5 patches
# Images found: 1
# Total images for author 628: 1, 6 patches
# Images found: 1
# Total images for author 629: 1, 6 patches
# Images found: 1
# Total images for author 630: 1, 7 patches
# Images found: 1
# Total images for author 631: 1, 7 patches
# Images found: 1
# Total images for author 632: 1, 7 patches
# Images found: 1
# Total images for author 633: 1, 4 patches
# Images found: 9
# Total images for author 634: 9, 69 patches
# Images found: 10
# Total images for author 635: 10, 48 patches
# Images found: 1
# Total images for author 636: 1, 6 patches
# Images found: 1
# Total images for author 637: 1, 4 patches
# Images found: 1
# Total images for author 638: 1, 8 patches
# Images found: 1
# Total images for author 639: 1, 5 patches
# Images found: 1
# Total images for author 640: 1, 8 patches
# Images found: 1
# Total images for author 641: 1, 5 patches
# Images found: 1
# Total images for author 642: 1, 5 patches
# Images found: 1
# Total images for author 643: 1, 9 patches
# Images found: 1
# Total images for author 644: 1, 6 patches
# Images found: 1
# Total images for author 645: 1, 5 patches
# Images found: 1
# Total images for author 647: 1, 6 patches
# Images found: 1
# Total images for author 648: 1, 6 patches
# Images found: 1
# Total images for author 649: 1, 7 patches
# Images found: 1
# Total images for author 650: 1, 8 patches
# Images found: 1
# Total images for author 651: 1, 6 patches
# Images found: 1
# Total images for author 652: 1, 4 patches
# Images found: 1
# Total images for author 653: 1, 4 patches
# Images found: 1
# Total images for author 654: 1, 8 patches
# Images found: 1
# Total images for author 655: 1, 3 patches
# Images found: 2
# Total images for author 658: 2, 14 patches
# Images found: 1
# Total images for author 659: 1, 7 patches
# Images found: 1
# Total images for author 660: 1, 5 patches
# Images found: 1
# Total images for author 661: 1, 8 patches
# Images found: 1
# Total images for author 662: 1, 5 patches
# Images found: 1
# Total images for author 663: 1, 6 patches
# Images found: 1
# Total images for author 664: 1, 6 patches
# Images found: 1
# Total images for author 665: 1, 8 patches
# Images found: 1
# Total images for author 666: 1, 5 patches
# Images found: 1
# Total images for author 667: 1, 5 patches
# Images found: 1
# Total images for author 668: 1, 8 patches
# Images found: 1
# Total images for author 669: 1, 2 patches
# Images found: 10
# Total images for author 670: 10, 71 patches
# Images found: 10
# Total images for author 671: 10, 78 patches
# Authors processed: 657
# Images processed: 1536
# Total patches: 9893

# %%
pic=cv2.imread(r'C:\Users\User\Desktop\вкр\content\data\000\a01-026u.png')

# %%
print(pic)
# Out:
# None
